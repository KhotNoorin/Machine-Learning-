# %% [markdown]
# <a href="https://colab.research.google.com/github/KhotNoorin/Machine-Learning-/blob/main/Linear_Regresson_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear regression

# %% [markdown]
# Simple Linear Regression
# 𝑦 = 𝛽0 + 𝛽1𝑥 + 𝜀
#
# Multiple Linear Regression – More than one independent variable
# Equation:
#
# 𝑦
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑥
# 1
# +
# 𝛽
# 2
# 𝑥
# 2
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑥
# 𝑛
# +
# 𝜀
# y=β
# 0
# ​
#  +β
# 1
# ​
#  x
# 1
# ​
#  +β
# 2
# ​
#  x
# 2
# ​
#  +⋯+β
# n
# ​
#  x
# n
# ​
#  +ε
#
# 🔹 Assumptions of Linear Regression:
# Linearity between independent and dependent variables
#
# Homoscedasticity (constant variance of errors)
#
# Independence of errors
#
# No multicollinearity (in multiple regression)
#
# Normal distribution of errors

# %% [markdown]
# How It Works
#
#
# 1.   Hypothesis: Predicts y using a linear equation.
# 2.   Loss Function: Measures error between predicted and actual values using Mean Squared Error (MSE):
# 3.  Optimization: Uses Gradient Descent or analytical solutions (like the Normal Equation) to minimize the MSE.

# %% [markdown]
# Limitations of Linear Regression
#
#
# 1.   Assumes Linear Relationship
# 2.   Sensitive to Outliers
# 3.   Multicollinearity
# 4.   Assumes Homoscedasticity (assumes that error variance is constant across all levels of input.)
# 5.    Assumes Independence of Errors
# 6.    No Automatic Feature Selection
# 7.    Not Great for Complex Problems
# 8.    Needs Numerical Inputs
# 9. Assumes Normality of Errors

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([2,4,6,8,10])

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x)

# %%
print("Intercept:", model.intercept_)  # constant term 'b'
print("Slope:", model.coef_[0])        # weight 'm' in y = mx + b
# Out:
# Intercept: 0.0
# Slope: 2.0

# %%
plt.scatter(x,y,color='Blue',label='Actual')
plt.plot(x,y_pred,color='Red',label="Predicted")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression")
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x1=np.array([
    [1000, 2],
    [2000, 6],
    [4000, 5],
    [9000, 7],
    [6000, 6],
    [4000, 4]
])

# %%
y1=np.array([200,300,400,700,800,900])

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
print("Predicted Prices:", y_pred)
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("Model Score (R²):", model.score(x_test, y_test))
# Out:
# Predicted Prices: [963.04347826 -50.        ]
# Coefficients: [ 1.60869565e-01 -2.93478261e+02]
# Intercept: 1389.1304347826087
# Model Score (R²): -139.94706994328922

# %% [markdown]
#  Manual Multiple Linear Regression

# %%
import numpy as np


X = np.array([
    [1, 2, 3],
    [2, 3, 4],
    [3, 4, 5],
    [4, 5, 6],
    [5, 6, 7]
], dtype=float)

y = np.array([10, 13, 16, 19, 22], dtype=float)

#Initialize parameters
n_samples, n_features = X.shape
weights = np.zeros(n_features)  # weights for each feature
bias = 0.0


alpha = 0.01
epochs = 1000

#Gradient Descent Loop
for i in range(epochs):
    y_pred = np.dot(X, weights) + bias     # predicted y
    error = y - y_pred                     # residuals

    # Compute gradients
    dw = (-2 / n_samples) * np.dot(X.T, error)
    db = (-2 / n_samples) * np.sum(error)

    # Update parameters
    weights -= alpha * dw
    bias -= alpha * db

    # Print loss every 100 epochs
    if i % 100 == 0:
        mse = np.mean(error ** 2)
        print(f"Epoch {i}: Loss = {mse:.4f}, Weights = {weights}, Bias = {bias:.4f}")

# model
print("\nFinal Weights:", weights)
print("Final Bias:", bias)
# Out:
# Epoch 0: Loss = 274.0000, Weights = [1.08 1.4  1.72], Bias = 0.3200
# Epoch 100: Loss = 0.3125, Weights = [0.34619785 1.12414846 1.90209908], Bias = 0.7780
# Epoch 200: Loss = 0.0874, Weights = [0.02600355 1.06564985 2.10529615], Bias = 1.0396
# Epoch 300: Loss = 0.0244, Weights = [-0.14331557  1.03471572  2.212747  ], Bias = 1.1780
# Epoch 400: Loss = 0.0068, Weights = [-0.23285171  1.01835771  2.26956714], Bias = 1.2512
# Epoch 500: Loss = 0.0019, Weights = [-0.28019853  1.00970758  2.2996137 ], Bias = 1.2899
# Epoch 600: Loss = 0.0005, Weights = [-0.30523559  1.00513338  2.31550235], Bias = 1.3104
# Epoch 700: Loss = 0.0001, Weights = [-0.31847521  1.00271454  2.32390429], Bias = 1.3212
# Epoch 800: Loss = 0.0000, Weights = [-0.32547634  1.00143545  2.32834724], Bias = 1.3269
# Epoch 900: Loss = 0.0000, Weights = [-0.32917855  1.00075907  2.33069668], Bias = 1.3299
#
# Final Weights: [-0.33112223  1.00040396  2.33193016]
# Final Bias: 1.3315261960467626

# %%
# Example prediction
x_test = np.array([6, 7, 8])  # new input
y_test_pred = np.dot(x_test, weights) + bias
print("\nPrediction for input [6, 7, 8]:", y_test_pred)
# Out:
# Prediction for input [6, 7, 8]: 25.003061782734846

# %% [markdown]
# Methods to Increase Accuracy in Linear Regression
#
#
# 1.   Feature Engineering
# 2.   Remove Irrelevant or Redundant Features
# 3. Feature Scaling / Normalization
# 4. Handle Outliers(box plot or zscore)
# 5. Remove Multicollinearity: High correlation between features confuses the model.
# 6. Regularization(L1 and L2)
# 7. Cross-Validation
# 8. Collect More or Better Data

# %%
#1
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
#3
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#6
from sklearn.linear_model import Ridge, Lasso

model = Ridge(alpha=1.0)  # or Lasso(alpha=0.1)
model.fit(x_train, y_train)
# Out:
# Ridge()

# %%
#7
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, y, cv=5, scoring='r2')
print("Average R² Score:", scores.mean())
# Out:
# Average R² Score: nan
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# ...

# %% [markdown]
# Accuracy measure in linear regression:
#
# Mean Squared Error (MSE)
#
# Root Mean Squared Error (RMSE)
#
# Mean Absolute Error (MAE)
#
# R² Score

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

y_true = np.array([2.2, 2.8, 4.5, 3.7, 5.5])
y_pred = np.array([2.0, 3.0, 4.0, 4.0, 5.0])

mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print(f"MSE: {mse:.3f}")
print(f"RMSE: {rmse:.3f}")
print(f"MAE: {mae:.3f}")
print(f"R² Score: {r2:.3f}")
# Out:
# MSE: 0.134
# RMSE: 0.366
# MAE: 0.340
# R² Score: 0.903

# %% [markdown]
# Activation Functions

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(0, x)

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

def softmax(x):
    exp_x = np.exp(x - np.max(x))  # for numerical stability
    return exp_x / np.sum(exp_x)
